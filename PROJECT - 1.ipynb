# %% [markdown]
# ### 1A _ENGLISH DICTIONARY APP

# %%
import json
print('Mainmenu \n\n 1.Add a word \n 2.Find the meaning \n 3.Update \n 4.exit \n')
while True:
    try:
        action=int(input('please select from the given main menu(1,2,3,4):'))
    except ValueError:
        print('!!! please enter integer values only!!!')
        print('#' *20)
    else:
        if action==4:
            e=input('Are yor sure you want to exit?(yes/no):')
            if e=='Yes' or e=='yes':
                print('Thank you have a nice day!!')
                print('#'*20)
                break
            else:
                continue
        elif action==1:
            word=input('Enter a new word:')
            meaning=input('Enter meaning of the word you entered:')
            add={word:meaning}
            with open('words.txt','a')as f:
                f.write(json.dumps(add))
                f.write('\n')
            print('word added succesfully')
            print('#'*20)
        
        elif action==2:
            find=input('Enter a word to find items meaning:')
            with open('words.txt','r')as f:
                data=f.read()
                if find in data:
                    print(f'meaning of the word you entered is : {meaning}')
                    print('#'*20)
        elif action==3:
            oldword=input('Enter a word to be updated:')
            with open('words.txt','r')as f:
                data=f.read()
                if oldword in data:
                    newword=input('enter a new word:')
                    data=data.replace(oldword,newword)
                    with open('words.txt','w')as file:
                          file.write(data)
                    print('{oldword} has been updated to {new word}')
                    print('#'*20)
                    continue
                
                else:
                    print('word not found')
                    print('#'*20)
                
        else:
            print('!!!please chose the correct option from mainmenu!!!')
            print('#'*20)
# Out:
# Mainmenu
#
#  1.Add a word
#  2.Find the meaning
#  3.Update
#  4.exit
#
# please select from the given main menu(1,2,3,4):4
# Are yor sure you want to exit?(yes/no):yes
# Thank you have a nice day!!
# ####################

# %% [markdown]
# ## 1B_Library Book Management System

# %%
import sqlite3 as sql
import tkinter as tk
import tkinter .ttk as ttk
import tkinter.messagebox as mb
import tkinter.simpledialog as sd
from tkinter import *

root=Tk()
root.title('.....Library Management Application.....')

def Database():
    global conn,cursor
    conn=sql.connect ('simple.db')
    cursor=conn.cursor()
    cursor.execute ('CREATE TABLE IF NOT EXISTS Booklibrary(Bookname TEXT,Auther TEXT,Year TEXT ,ISBN TEXT )')
def create():
    if BOOKNAME.get()==""or AUTHER.get()==""or YEAR.get()==""or ISBN.get()=="":
        txt_result.config(text='Please Enter all the fields',fd='red')
    else:
        Database()
        cursor.execute('INSERT INTO Booklibrary(Bookname,Auther,Year,ISBN)values(?,?,?,?)',(str(BOOKNAME.get()),str(AUTHER.get()),str(YEAR.get()),str(ISBN.get())))
        conn.commit()
        BOOKNAME.set("")
        AUTHER.set("")
        YEAR.set("")
        ISBN.set("")
        cursor.close()
        conn.close()
        text_result.config(text="Record Inserted !",fg='green')
def Read():
    tree.delete(*tree.get_children())
    Database()
    cursor.execute('SELECT * FROM Booklibrary ORDER BY Auther ASC')
    fetch=cursor.fetchall()
    for data in fetch:
        tree.insert('','end',values=(data[0],data[1],data[3]))
        cursor.close()
        txt_result.config(text='Successfully fetched data !',fg='black')
def Exit():
    result=mb.askquestion('Do you want to Exit ?(y/n)',icon='warning')
    if result=='yes':
        root.destroy()
        exit()
        
# Variables
BOOKNAME=StringVar()
AUTHER=StringVar()
YEAR=StringVar()
ISBN=StringVar()

# FRAMES
Top=Frame(root,width=900,height=50,bd=8,relief='raise')
Top.pack(side=TOP)
Left=Frame(root,width=300,height=500,bd=8,relief='raise')
Left.pack(side=LEFT)
Right=Frame(root,width=600,height=500,bd=8,relief='raise')
Right.pack(side=RIGHT)

Forms=Frame(Left,width=400,height=1000)
Forms.pack(side="top")

#buttons
Buttons=Frame(Left,width=300,height=100,bd=8,relief='raise')
Buttons.pack(side="bottom")

#Labels
txt_tittle=Label(Top,width=900,font=('arial',24),text='.....Library Management Application.....')
txt_tittle.pack()
txt_Bookname=Label(Forms,text='Bookname',font=('arial',16),bd=15)
txt_Bookname.grid(row=0,stick='e')
txt_Auther=Label(Forms,text='Auther',font=('arial',16),bd=15)
txt_Auther.grid(row=1,stick='e')
txt_Year=Label(Forms,text='Year',font=('arial',16),bd=15)
txt_Year.grid(row=2,stick='e')
txt_ISBN=Label(Forms,text='ISBN',font=('arial',16),bd=15)
txt_ISBN.grid(row=3,stick='e')
txt_result=Label(Buttons)
txt_result.pack(side=TOP)

#Entry widgets
Bookname=Entry(Forms,textvariable=BOOKNAME,width=30)
Bookname.grid(row=0,column=1)
Auther=Entry(Forms,textvariable=AUTHER,width=30)
Auther.grid(row=1,column=1)
Year=Entry(Forms,textvariable=YEAR,width=30)
Year.grid(row=2,column=1)
ISBN=Entry(Forms,textvariable=ISBN,width=30)
ISBN.grid(row=3,column=1)

#Button widgets
btn_display=Button(Buttons,width=10,text="Display")
btn_display.pack(side="left")
btn_search=Button(Buttons,width=10,text="Search")
btn_search.pack(side="left")
btn_add=Button(Buttons,width=10,text="Add",command=create)
btn_add.pack(side="left")
btn_issue=Button(Buttons,width=10,text="Issue",command=Read)
btn_issue.pack(side="left")
btn_delete=Button(Buttons,width=10,text="Delete")
btn_delete.pack(side="left")
btn_exit=Button(Buttons,width=10,text="Exit",command=Exit)
btn_exit.pack(side="left")

#list widgets
scrollbary=Scrollbar(Right,orient=VERTICAL)
scrollbarx=Scrollbar(Left,orient=HORIZONTAL)

tree=ttk.Treeview(Right,columns=('Book','Auther','Year','Isbn'))

scrollbary.config(command=tree.yview)
scrollbary.pack(side="right",fill=Y)
scrollbarx.config(command=tree.xview)
scrollbarx.pack(side="right",fill=X)
tree.heading('Book',text='Book',anchor=W)
tree.heading('Auther',text='Auther',anchor=W)
tree.heading('Year',text='Year',anchor=W)
tree.heading('Isbn',text='Isbn',anchor=W)
tree.column('#0',stretch=NO,minwidth=0,width=0)
tree.column('#1',stretch=NO,minwidth=0,width=80)
tree.column('#2',stretch=NO,minwidth=0,width=120)
tree.column('#3',stretch=NO,minwidth=0,width=160)
tree.pack()

#instalization
root.mainloop()
